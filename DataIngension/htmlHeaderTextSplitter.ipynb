# %%
html_string = """
<html>
    <body>
        <h1>testing 1</h1>  
        <p>This is a paragraph under heading 1.</p>
        <h2>testing 2</h2>
        <p>This is a paragraph under heading 2.</p>
        <h3>testing 3</h3>
        <p>This is a paragraph under heading 3.</p>
    </body>
</html>
"""

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter
html_splitter = HTMLHeaderTextSplitter(
    headers_to_split_on=[
        ("h1", "Header 1"),
        ("h2", "Header 2"),
        ("h3", "Header 3"),
    ]
)
html_header_splitter = html_splitter.split_text(html_string)
html_header_splitter
# Out:
# [Document(metadata={'Header 1': 'testing 1'}, page_content='testing 1'),
#  Document(metadata={'Header 1': 'testing 1'}, page_content='This is a paragraph under heading 1.'),
#  Document(metadata={'Header 1': 'testing 1', 'Header 2': 'testing 2'}, page_content='testing 2'),
#  Document(metadata={'Header 1': 'testing 1', 'Header 2': 'testing 2'}, page_content='This is a paragraph under heading 2.'),
#  Document(metadata={'Header 1': 'testing 1', 'Header 2': 'testing 2', 'Header 3': 'testing 3'}, page_content='testing 3'),
#  Document(metadata={'Header 1': 'testing 1', 'Header 2': 'testing 2', 'Header 3': 'testing 3'}, page_content='This is a paragraph under heading 3.')]
